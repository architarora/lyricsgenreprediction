# %% [markdown]
# # Spotify API

# %% [markdown]
# ### Main Goal: Utilizing the Spotify API, determine other features of each track from our trimmed dataset to determine if those other features can be used to correctly classify the genre.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np

import findspark
findspark.init()
from pyspark import SparkContext
sc = SparkContext()

# %% [markdown]
# ### Utilized a Python package called Spotipy

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = "ed85fecdaeeb475ebe9a9f54a40eb054",client_secret='8001bae67076404bbb1a5980f2db94b1')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# # Pandas

# %%
songs = pd.read_csv("cleaned_6_miheer8000rockpop.csv")

# %%
songs.head()
# Out:
#     index genre                                             lyrics  \
# 0  192053  Rock  It all started way back then A lifetime of rob...
# 1  231708  Rock  Amidst the burning rubble the spirit still liv...
# 2  350323  Rock  Is there anybody out there? Anyone that's love...
# 3   37853  Rock  Here is the room that we shared The room that ...
# 4  107765  Rock  I do it on a whim, its rhyme without reason wh...
#
#                          song         artist
# 0        crime-of-the-century   the-business
# 1               100-years-war        faction
# 2      how-do-ya-feel-tonight    bryan-adams
# 3  i-haven-t-changed-the-room  barry-manilow
# 4              without-reason           fray

# %%
songs['song_artist'] = songs['song'] + ":" + songs['artist']
songs.head()
# Out:
#     index genre                                             lyrics  \
# 0  192053  Rock  It all started way back then A lifetime of rob...
# 1  231708  Rock  Amidst the burning rubble the spirit still liv...
# 2  350323  Rock  Is there anybody out there? Anyone that's love...
# 3   37853  Rock  Here is the room that we shared The room that ...
# 4  107765  Rock  I do it on a whim, its rhyme without reason wh...
#
#                          song         artist  \
# 0        crime-of-the-century   the-business
# 1               100-years-war        faction
# 2      how-do-ya-feel-tonight    bryan-adams
# 3  i-haven-t-changed-the-room  barry-manilow
# 4              without-reason           fray
#
#                                 song_artist
# 0         crime-of-the-century:the-business
# 1                     100-years-war:faction
# 2        how-do-ya-feel-tonight:bryan-adams
# 3  i-haven-t-changed-the-room:barry-manilow
# 4                       without-reason:fray

# %%
def clean_artist(artist):
    artist.replace('-', ' ')
    return artist.upper()

# %% [markdown]
# ### Find_song contains one Spotify API calls. The call is a get request which searches the song and gets the id of the song that Spotify stores and also ensures the artist from our dataset matches the artist from Spotify.
# (Takes about an hour to run because of the number of API calls being made.)

# %%
def find_song(song_artist):
    song_name, artist = song_artist.split(":")
    artist = clean_artist(artist)
    results = sp.search(q='track:' + song_name, type='track')
    lenTracks = len(results['tracks']['items'])
    if lenTracks == 0:
        return None
    idS = None
    for i in range(lenTracks):
        if results['tracks']['items'][i]['album']['artists'][0]['name'].upper() == artist:
            idS = results['tracks']['items'][i]['id']
    return idS     
# newresults = sp.audio_features(idS)
# print(newresults)

# %% [markdown]
# ### After finding the ID of the song, we map each id to the audio features of the song to obtain the danceability, acousticness, etc. measures which we will use to classify the genre.

# %%
songIDS = songs['song_artist'].map(lambda x: find_song(x)).dropna()
# Out:
# retrying ...1secs

# %%
len(songIDS)
# Out:
# 1343

# %%
audio_feat = songIDS.map(lambda x: sp.audio_features(x))

# %%
series = audio_feat.map(lambda x: x[0])
# Out:
# 5     {'danceability': 0.376, 'energy': 0.948, 'key'...
# 10    {'danceability': 0.397, 'energy': 0.446, 'key'...
# 22    {'danceability': 0.518, 'energy': 0.203, 'key'...
# 42    {'danceability': 0.57, 'energy': 0.823, 'key':...
# 66    {'danceability': 0.64, 'energy': 0.232, 'key':...
# Name: song_artist, dtype: object

# %%
df = pd.DataFrame(series.tolist())
df.T
# Out:
#                                                                0     \
# acousticness                                               0.000124
# analysis_url      https://api.spotify.com/v1/audio-analysis/0Ytl...
# danceability                                                  0.376
# duration_ms                                                  171293
# energy                                                        0.948
# id                                           0YtlU1KOPcxvNyiJTzqnCd
# instrumentalness                                           0.000104
# key                                                               9
# liveness                                                      0.119
# loudness                                                     -4.683
# mode                                                              1
# speechiness                                                   0.108
# tempo                                                        97.085
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/0YtlU1KOPcxv...
# type                                                 audio_features
# uri                            spotify:track:0YtlU1KOPcxvNyiJTzqnCd
# valence                                                       0.477
#
#                                                                1     \
# acousticness                                                  0.287
# analysis_url      https://api.spotify.com/v1/audio-analysis/2C0Y...
# danceability                                                  0.397
# duration_ms                                                  288813
# energy                                                        0.446
# id                                           2C0YMWYyTjhRpEz1Xk42Hk
# instrumentalness                                            0.00866
# key                                                               4
# liveness                                                      0.109
# loudness                                                     -7.411
# mode                                                              1
# speechiness                                                  0.0248
# tempo                                                       170.541
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/2C0YMWYyTjhR...
# type                                                 audio_features
# uri                            spotify:track:2C0YMWYyTjhRpEz1Xk42Hk
# valence                                                       0.199
#
#                                                                2     \
# acousticness                                                  0.586
# analysis_url      https://api.spotify.com/v1/audio-analysis/09at...
# danceability                                                  0.518
# duration_ms                                                  223840
# energy                                                        0.203
# id                                           09atT5JgSXIcq9v9H9qoQp
# instrumentalness                                           1.63e-06
# key                                                               9
# liveness                                                      0.147
# loudness                                                    -14.529
# mode                                                              1
# speechiness                                                  0.0275
# tempo                                                       103.305
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/09atT5JgSXIc...
# type                                                 audio_features
# uri                            spotify:track:09atT5JgSXIcq9v9H9qoQp
# valence                                                       0.144
#
#                                                                3     \
# acousticness                                                 0.0398
# analysis_url      https://api.spotify.com/v1/audio-analysis/54k4...
# danceability                                                   0.57
# duration_ms                                                  182040
# energy                                                        0.823
# id                                           54k4yt6SAkvlPcTMe4PKeC
# instrumentalness                                                  0
# key                                                               8
# liveness                                                     0.0996
# loudness                                                     -4.761
# mode                                                              1
# speechiness                                                  0.0294
# tempo                                                       133.117
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/54k4yt6SAkvl...
# type                                                 audio_features
# uri                            spotify:track:54k4yt6SAkvlPcTMe4PKeC
# valence                                                        0.93
#
#                                                                4     \
# acousticness                                                  0.674
# analysis_url      https://api.spotify.com/v1/audio-analysis/3MPz...
# danceability                                                   0.64
# duration_ms                                                  265693
# energy                                                        0.232
# id                                           3MPzfijILwzlhhvBFKOTEB
# instrumentalness                                           4.66e-06
# key                                                               5
# liveness                                                      0.104
# loudness                                                    -13.337
# mode                                                              1
# speechiness                                                   0.027
# tempo                                                       147.676
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/3MPzfijILwzl...
# type                                                 audio_features
# uri                            spotify:track:3MPzfijILwzlhhvBFKOTEB
# valence                                                       0.263
#
#                                                                5     \
# acousticness                                                 0.0101
# analysis_url      https://api.spotify.com/v1/audio-analysis/3Cga...
# danceability                                                   0.39
# duration_ms                                                  187667
# energy                                                        0.887
# id                                           3CgaJaolETpSJlY0g7lMmf
# instrumentalness                                            3.2e-05
# key                                                               9
# liveness                                                      0.365
# loudness                                                     -4.782
# mode                                                              0
# speechiness                                                  0.0622
# tempo                                                         86.27
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/3CgaJaolETpS...
# type                                                 audio_features
# uri                            spotify:track:3CgaJaolETpSJlY0g7lMmf
# valence                                                       0.494
#
#                                                                6     \
# acousticness                                                0.00275
# analysis_url      https://api.spotify.com/v1/audio-analysis/7xdd...
# danceability                                                  0.508
# duration_ms                                                  238500
# energy                                                        0.875
# id                                           7xddswKFyyesNjV8wpCGLo
# instrumentalness                                                  0
# key                                                               9
# liveness                                                      0.319
# loudness                                                     -3.262
# mode                                                              0
# speechiness                                                  0.0615
# tempo                                                       160.039
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/7xddswKFyyes...
# type                                                 audio_features
# uri                            spotify:track:7xddswKFyyesNjV8wpCGLo
# valence                                                        0.14
#
#                                                                7     \
# acousticness                                                 0.0632
# analysis_url      https://api.spotify.com/v1/audio-analysis/006R...
# danceability                                                  0.352
# duration_ms                                                  267893
# energy                                                        0.791
# id                                           006RKA1XTkko2TWvLzln9p
# instrumentalness                                           5.56e-06
# key                                                               4
# liveness                                                      0.621
# loudness                                                     -4.929
# mode                                                              0
# speechiness                                                   0.101
# tempo                                                       145.487
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/006RKA1XTkko...
# type                                                 audio_features
# uri                            spotify:track:006RKA1XTkko2TWvLzln9p
# valence                                                       0.169
#
#                                                                8     \
# acousticness                                                  0.322
# analysis_url      https://api.spotify.com/v1/audio-analysis/5ZQV...
# danceability                                                  0.416
# duration_ms                                                  243787
# energy                                                        0.545
# id                                           5ZQV9gdVC5Vvaw3BCPl2p6
# instrumentalness                                                  0
# key                                                               6
# liveness                                                      0.105
# loudness                                                     -6.891
# mode                                                              1
# speechiness                                                  0.0261
# tempo                                                       168.013
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/5ZQV9gdVC5Vv...
# type                                                 audio_features
# uri                            spotify:track:5ZQV9gdVC5Vvaw3BCPl2p6
# valence                                                       0.195
#
#                                                                9     \
# acousticness                                                 0.0905
# analysis_url      https://api.spotify.com/v1/audio-analysis/7jHq...
# danceability                                                  0.388
# duration_ms                                                  161007
# energy                                                         0.99
# id                                           7jHqV4pe8Yoh5A9oYoGRWt
# instrumentalness                                           0.000229
# key                                                               3
# liveness                                                      0.192
# loudness                                                     -3.114
# mode                                                              1
# speechiness                                                  0.0757
# tempo                                                       145.518
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/7jHqV4pe8Yoh...
# type                                                 audio_features
# uri                            spotify:track:7jHqV4pe8Yoh5A9oYoGRWt
# valence                                                       0.626
#
#                                         ...                          \
# acousticness                            ...
# analysis_url                            ...
# danceability                            ...
# duration_ms                             ...
# energy                                  ...
# id                                      ...
# instrumentalness                        ...
# key                                     ...
# liveness                                ...
# loudness                                ...
# mode                                    ...
# speechiness                             ...
# tempo                                   ...
# time_signature                          ...
# track_href                              ...
# type                                    ...
# uri                                     ...
# valence                                 ...
#
#                                                                1333  \
# acousticness                                                0.00856
# analysis_url      https://api.spotify.com/v1/audio-analysis/4wHh...
# danceability                                                  0.728
# duration_ms                                                  165240
# energy                                                        0.846
# id                                           4wHhLyYVpwgnAzIGiVoTRj
# instrumentalness                                            0.00789
# key                                                               4
# liveness                                                      0.355
# loudness                                                     -6.783
# mode                                                              1
# speechiness                                                  0.0622
# tempo                                                       122.054
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/4wHhLyYVpwgn...
# type                                                 audio_features
# uri                            spotify:track:4wHhLyYVpwgnAzIGiVoTRj
# valence                                                       0.742
#
#                                                                1334  \
# acousticness                                                 0.0944
# analysis_url      https://api.spotify.com/v1/audio-analysis/3uqz...
# danceability                                                  0.723
# duration_ms                                                  192667
# energy                                                         0.69
# id                                           3uqzRnkdAZZrTX18xdBQ73
# instrumentalness                                           8.77e-06
# key                                                               4
# liveness                                                      0.196
# loudness                                                     -9.254
# mode                                                              1
# speechiness                                                    0.06
# tempo                                                       168.515
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/3uqzRnkdAZZr...
# type                                                 audio_features
# uri                            spotify:track:3uqzRnkdAZZrTX18xdBQ73
# valence                                                       0.779
#
#                                                                1335  \
# acousticness                                                   0.15
# analysis_url      https://api.spotify.com/v1/audio-analysis/0jyB...
# danceability                                                  0.624
# duration_ms                                                  292720
# energy                                                        0.897
# id                                           0jyByiP8zEfCi9Xjjuy3ce
# instrumentalness                                           2.96e-06
# key                                                               1
# liveness                                                      0.126
# loudness                                                     -5.234
# mode                                                              1
# speechiness                                                  0.0406
# tempo                                                       102.212
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/0jyByiP8zEfC...
# type                                                 audio_features
# uri                            spotify:track:0jyByiP8zEfCi9Xjjuy3ce
# valence                                                       0.587
#
#                                                                1336  \
# acousticness                                                 0.0606
# analysis_url      https://api.spotify.com/v1/audio-analysis/5aYy...
# danceability                                                  0.694
# duration_ms                                                  273427
# energy                                                        0.886
# id                                           5aYyJsxgHxHk9BFnHs4UFj
# instrumentalness                                           9.69e-06
# key                                                               0
# liveness                                                     0.0596
# loudness                                                     -6.908
# mode                                                              1
# speechiness                                                  0.0649
# tempo                                                       124.792
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/5aYyJsxgHxHk...
# type                                                 audio_features
# uri                            spotify:track:5aYyJsxgHxHk9BFnHs4UFj
# valence                                                       0.783
#
#                                                                1337  \
# acousticness                                                  0.226
# analysis_url      https://api.spotify.com/v1/audio-analysis/298M...
# danceability                                                  0.516
# duration_ms                                                  294507
# energy                                                        0.545
# id                                           298M3RVPq5D1EhvgDzu7Mi
# instrumentalness                                                  0
# key                                                              10
# liveness                                                     0.0817
# loudness                                                     -7.687
# mode                                                              1
# speechiness                                                  0.0294
# tempo                                                       144.338
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/298M3RVPq5D1...
# type                                                 audio_features
# uri                            spotify:track:298M3RVPq5D1EhvgDzu7Mi
# valence                                                       0.272
#
#                                                                1338  \
# acousticness                                                 0.0167
# analysis_url      https://api.spotify.com/v1/audio-analysis/4AYh...
# danceability                                                  0.718
# duration_ms                                                  272147
# energy                                                        0.751
# id                                           4AYhsnQ43KBckV3RBagFPJ
# instrumentalness                                           1.78e-05
# key                                                               6
# liveness                                                      0.084
# loudness                                                     -5.965
# mode                                                              0
# speechiness                                                   0.033
# tempo                                                       101.971
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/4AYhsnQ43KBc...
# type                                                 audio_features
# uri                            spotify:track:4AYhsnQ43KBckV3RBagFPJ
# valence                                                       0.593
#
#                                                                1339  \
# acousticness                                                0.00136
# analysis_url      https://api.spotify.com/v1/audio-analysis/1StV...
# danceability                                                  0.677
# duration_ms                                                  337200
# energy                                                        0.678
# id                                           1StVq7G98jtRPttTbliku7
# instrumentalness                                            0.00478
# key                                                               7
# liveness                                                     0.0489
# loudness                                                     -6.983
# mode                                                              0
# speechiness                                                  0.0833
# tempo                                                       121.026
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/1StVq7G98jtR...
# type                                                 audio_features
# uri                            spotify:track:1StVq7G98jtRPttTbliku7
# valence                                                       0.404
#
#                                                                1340  \
# acousticness                                                 0.0506
# analysis_url      https://api.spotify.com/v1/audio-analysis/6gQr...
# danceability                                                  0.691
# duration_ms                                                  223240
# energy                                                        0.927
# id                                           6gQrEwP4pFpszAnMfmASns
# instrumentalness                                           7.24e-06
# key                                                               4
# liveness                                                      0.132
# loudness                                                     -6.925
# mode                                                              1
# speechiness                                                  0.0297
# tempo                                                       127.997
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/6gQrEwP4pFps...
# type                                                 audio_features
# uri                            spotify:track:6gQrEwP4pFpszAnMfmASns
# valence                                                       0.926
#
#                                                                1341  \
# acousticness                                                  0.687
# analysis_url      https://api.spotify.com/v1/audio-analysis/1Yid...
# danceability                                                  0.707
# duration_ms                                                  194187
# energy                                                        0.656
# id                                           1Yid1jOsjDdITUUAL9I88s
# instrumentalness                                                  0
# key                                                               0
# liveness                                                      0.163
# loudness                                                     -5.588
# mode                                                              1
# speechiness                                                   0.104
# tempo                                                        90.182
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/1Yid1jOsjDdI...
# type                                                 audio_features
# uri                            spotify:track:1Yid1jOsjDdITUUAL9I88s
# valence                                                        0.77
#
#                                                                1342
# acousticness                                                 0.0337
# analysis_url      https://api.spotify.com/v1/audio-analysis/67NK...
# danceability                                                  0.685
# duration_ms                                                  259040
# energy                                                          0.6
# id                                           67NKaMOPOJKlWsYW6mVhSs
# instrumentalness                                           0.000365
# key                                                               9
# liveness                                                      0.156
# loudness                                                    -14.004
# mode                                                              0
# speechiness                                                  0.0517
# tempo                                                       103.015
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/67NKaMOPOJKl...
# type                                                 audio_features
# uri                            spotify:track:67NKaMOPOJKlWsYW6mVhSs
# valence                                                       0.738
#
# [18 rows x 1343 columns]

# %%
songIDS.head()
# Out:
# 5     0YtlU1KOPcxvNyiJTzqnCd
# 10    2C0YMWYyTjhRpEz1Xk42Hk
# 22    09atT5JgSXIcq9v9H9qoQp
# 42    54k4yt6SAkvlPcTMe4PKeC
# 66    3MPzfijILwzlhhvBFKOTEB
# Name: song_artist, dtype: object

# %% [markdown]
# ### Afterwards, we need to merge the audio features with the original dataset using the ID of the song in order to get the genre.

# %%
songNames = songIDS.map(lambda x: (x, sp.track(x)))

# %%
songNames = songNames.map(lambda x: (x[0], x[1]['name']))
dfNames = pd.DataFrame(songNames.tolist())
dfNames = dfNames.set_index(0)
dfNames = dfNames.rename(index = str, columns = {1 : 'Song Name'})
dfNames.head()
# Out:
#                                      Song Name
# 0
# 0YtlU1KOPcxvNyiJTzqnCd          Pale Blue Face
# 2C0YMWYyTjhRpEz1Xk42Hk  Seperti Yang Kau Minta
# 09atT5JgSXIcq9v9H9qoQp              Then Again
# 54k4yt6SAkvlPcTMe4PKeC         Walk To The Bay
# 3MPzfijILwzlhhvBFKOTEB            I Showed Her

# %%
dfCombined = df.join(dfNames, on='id', how='inner')

# %%
dfCombined.T
# Out:
#                                                                0     \
# acousticness                                               0.000124
# analysis_url      https://api.spotify.com/v1/audio-analysis/0Ytl...
# danceability                                                  0.376
# duration_ms                                                  171293
# energy                                                        0.948
# id                                           0YtlU1KOPcxvNyiJTzqnCd
# instrumentalness                                           0.000104
# key                                                               9
# liveness                                                      0.119
# loudness                                                     -4.683
# mode                                                              1
# speechiness                                                   0.108
# tempo                                                        97.085
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/0YtlU1KOPcxv...
# type                                                 audio_features
# uri                            spotify:track:0YtlU1KOPcxvNyiJTzqnCd
# valence                                                       0.477
# Song Name                                            Pale Blue Face
#
#                                                                1     \
# acousticness                                                  0.287
# analysis_url      https://api.spotify.com/v1/audio-analysis/2C0Y...
# danceability                                                  0.397
# duration_ms                                                  288813
# energy                                                        0.446
# id                                           2C0YMWYyTjhRpEz1Xk42Hk
# instrumentalness                                            0.00866
# key                                                               4
# liveness                                                      0.109
# loudness                                                     -7.411
# mode                                                              1
# speechiness                                                  0.0248
# tempo                                                       170.541
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/2C0YMWYyTjhR...
# type                                                 audio_features
# uri                            spotify:track:2C0YMWYyTjhRpEz1Xk42Hk
# valence                                                       0.199
# Song Name                                    Seperti Yang Kau Minta
#
#                                                                2     \
# acousticness                                                  0.586
# analysis_url      https://api.spotify.com/v1/audio-analysis/09at...
# danceability                                                  0.518
# duration_ms                                                  223840
# energy                                                        0.203
# id                                           09atT5JgSXIcq9v9H9qoQp
# instrumentalness                                           1.63e-06
# key                                                               9
# liveness                                                      0.147
# loudness                                                    -14.529
# mode                                                              1
# speechiness                                                  0.0275
# tempo                                                       103.305
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/09atT5JgSXIc...
# type                                                 audio_features
# uri                            spotify:track:09atT5JgSXIcq9v9H9qoQp
# valence                                                       0.144
# Song Name                                                Then Again
#
#                                                                3     \
# acousticness                                                 0.0398
# analysis_url      https://api.spotify.com/v1/audio-analysis/54k4...
# danceability                                                   0.57
# duration_ms                                                  182040
# energy                                                        0.823
# id                                           54k4yt6SAkvlPcTMe4PKeC
# instrumentalness                                                  0
# key                                                               8
# liveness                                                     0.0996
# loudness                                                     -4.761
# mode                                                              1
# speechiness                                                  0.0294
# tempo                                                       133.117
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/54k4yt6SAkvl...
# type                                                 audio_features
# uri                            spotify:track:54k4yt6SAkvlPcTMe4PKeC
# valence                                                        0.93
# Song Name                                           Walk To The Bay
#
#                                                                4     \
# acousticness                                                  0.674
# analysis_url      https://api.spotify.com/v1/audio-analysis/3MPz...
# danceability                                                   0.64
# duration_ms                                                  265693
# energy                                                        0.232
# id                                           3MPzfijILwzlhhvBFKOTEB
# instrumentalness                                           4.66e-06
# key                                                               5
# liveness                                                      0.104
# loudness                                                    -13.337
# mode                                                              1
# speechiness                                                   0.027
# tempo                                                       147.676
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/3MPzfijILwzl...
# type                                                 audio_features
# uri                            spotify:track:3MPzfijILwzlhhvBFKOTEB
# valence                                                       0.263
# Song Name                                              I Showed Her
#
#                                                                5     \
# acousticness                                                 0.0101
# analysis_url      https://api.spotify.com/v1/audio-analysis/3Cga...
# danceability                                                   0.39
# duration_ms                                                  187667
# energy                                                        0.887
# id                                           3CgaJaolETpSJlY0g7lMmf
# instrumentalness                                            3.2e-05
# key                                                               9
# liveness                                                      0.365
# loudness                                                     -4.782
# mode                                                              0
# speechiness                                                  0.0622
# tempo                                                         86.27
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/3CgaJaolETpS...
# type                                                 audio_features
# uri                            spotify:track:3CgaJaolETpSJlY0g7lMmf
# valence                                                       0.494
# Song Name                                              Sucker & Dry
#
#                                                                6     \
# acousticness                                                0.00275
# analysis_url      https://api.spotify.com/v1/audio-analysis/7xdd...
# danceability                                                  0.508
# duration_ms                                                  238500
# energy                                                        0.875
# id                                           7xddswKFyyesNjV8wpCGLo
# instrumentalness                                                  0
# key                                                               9
# liveness                                                      0.319
# loudness                                                     -3.262
# mode                                                              0
# speechiness                                                  0.0615
# tempo                                                       160.039
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/7xddswKFyyes...
# type                                                 audio_features
# uri                            spotify:track:7xddswKFyyesNjV8wpCGLo
# valence                                                        0.14
# Song Name                         Bored To Death - Steve Aoki Remix
#
#                                                                7     \
# acousticness                                                 0.0632
# analysis_url      https://api.spotify.com/v1/audio-analysis/006R...
# danceability                                                  0.352
# duration_ms                                                  267893
# energy                                                        0.791
# id                                           006RKA1XTkko2TWvLzln9p
# instrumentalness                                           5.56e-06
# key                                                               4
# liveness                                                      0.621
# loudness                                                     -4.929
# mode                                                              0
# speechiness                                                   0.101
# tempo                                                       145.487
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/006RKA1XTkko...
# type                                                 audio_features
# uri                            spotify:track:006RKA1XTkko2TWvLzln9p
# valence                                                       0.169
# Song Name         Day Eight: School - Live in Rotterdam in Septe...
#
#                                                                8     \
# acousticness                                                  0.322
# analysis_url      https://api.spotify.com/v1/audio-analysis/5ZQV...
# danceability                                                  0.416
# duration_ms                                                  243787
# energy                                                        0.545
# id                                           5ZQV9gdVC5Vvaw3BCPl2p6
# instrumentalness                                                  0
# key                                                               6
# liveness                                                      0.105
# loudness                                                     -6.891
# mode                                                              1
# speechiness                                                  0.0261
# tempo                                                       168.013
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/5ZQV9gdVC5Vv...
# type                                                 audio_features
# uri                            spotify:track:5ZQV9gdVC5Vvaw3BCPl2p6
# valence                                                       0.195
# Song Name                                Best Not to Think About It
#
#                                                                9     \
# acousticness                                                 0.0905
# analysis_url      https://api.spotify.com/v1/audio-analysis/7jHq...
# danceability                                                  0.388
# duration_ms                                                  161007
# energy                                                         0.99
# id                                           7jHqV4pe8Yoh5A9oYoGRWt
# instrumentalness                                           0.000229
# key                                                               3
# liveness                                                      0.192
# loudness                                                     -3.114
# mode                                                              1
# speechiness                                                  0.0757
# tempo                                                       145.518
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/7jHqV4pe8Yoh...
# type                                                 audio_features
# uri                            spotify:track:7jHqV4pe8Yoh5A9oYoGRWt
# valence                                                       0.626
# Song Name                                                 Evil Hand
#
#                                         ...                          \
# acousticness                            ...
# analysis_url                            ...
# danceability                            ...
# duration_ms                             ...
# energy                                  ...
# id                                      ...
# instrumentalness                        ...
# key                                     ...
# liveness                                ...
# loudness                                ...
# mode                                    ...
# speechiness                             ...
# tempo                                   ...
# time_signature                          ...
# track_href                              ...
# type                                    ...
# uri                                     ...
# valence                                 ...
# Song Name                               ...
#
#                                                                1333  \
# acousticness                                                0.00856
# analysis_url      https://api.spotify.com/v1/audio-analysis/4wHh...
# danceability                                                  0.728
# duration_ms                                                  165240
# energy                                                        0.846
# id                                           4wHhLyYVpwgnAzIGiVoTRj
# instrumentalness                                            0.00789
# key                                                               4
# liveness                                                      0.355
# loudness                                                     -6.783
# mode                                                              1
# speechiness                                                  0.0622
# tempo                                                       122.054
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/4wHhLyYVpwgn...
# type                                                 audio_features
# uri                            spotify:track:4wHhLyYVpwgnAzIGiVoTRj
# valence                                                       0.742
# Song Name                       Tall Story Teller - Megamix-Version
#
#                                                                1334  \
# acousticness                                                 0.0944
# analysis_url      https://api.spotify.com/v1/audio-analysis/3uqz...
# danceability                                                  0.723
# duration_ms                                                  192667
# energy                                                         0.69
# id                                           3uqzRnkdAZZrTX18xdBQ73
# instrumentalness                                           8.77e-06
# key                                                               4
# liveness                                                      0.196
# loudness                                                     -9.254
# mode                                                              1
# speechiness                                                    0.06
# tempo                                                       168.515
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/3uqzRnkdAZZr...
# type                                                 audio_features
# uri                            spotify:track:3uqzRnkdAZZrTX18xdBQ73
# valence                                                       0.779
# Song Name                                           Woke Up In Love
#
#                                                                1335  \
# acousticness                                                   0.15
# analysis_url      https://api.spotify.com/v1/audio-analysis/0jyB...
# danceability                                                  0.624
# duration_ms                                                  292720
# energy                                                        0.897
# id                                           0jyByiP8zEfCi9Xjjuy3ce
# instrumentalness                                           2.96e-06
# key                                                               1
# liveness                                                      0.126
# loudness                                                     -5.234
# mode                                                              1
# speechiness                                                  0.0406
# tempo                                                       102.212
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/0jyByiP8zEfC...
# type                                                 audio_features
# uri                            spotify:track:0jyByiP8zEfCi9Xjjuy3ce
# valence                                                       0.587
# Song Name                             Matkustanut oon - Captain-mix
#
#                                                                1336  \
# acousticness                                                 0.0606
# analysis_url      https://api.spotify.com/v1/audio-analysis/5aYy...
# danceability                                                  0.694
# duration_ms                                                  273427
# energy                                                        0.886
# id                                           5aYyJsxgHxHk9BFnHs4UFj
# instrumentalness                                           9.69e-06
# key                                                               0
# liveness                                                     0.0596
# loudness                                                     -6.908
# mode                                                              1
# speechiness                                                  0.0649
# tempo                                                       124.792
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/5aYyJsxgHxHk...
# type                                                 audio_features
# uri                            spotify:track:5aYyJsxgHxHk9BFnHs4UFj
# valence                                                       0.783
# Song Name                                             Rio Do Brasil
#
#                                                                1337  \
# acousticness                                                  0.226
# analysis_url      https://api.spotify.com/v1/audio-analysis/298M...
# danceability                                                  0.516
# duration_ms                                                  294507
# energy                                                        0.545
# id                                           298M3RVPq5D1EhvgDzu7Mi
# instrumentalness                                                  0
# key                                                              10
# liveness                                                     0.0817
# loudness                                                     -7.687
# mode                                                              1
# speechiness                                                  0.0294
# tempo                                                       144.338
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/298M3RVPq5D1...
# type                                                 audio_features
# uri                            spotify:track:298M3RVPq5D1EhvgDzu7Mi
# valence                                                       0.272
# Song Name                                            Volver a Nacer
#
#                                                                1338  \
# acousticness                                                 0.0167
# analysis_url      https://api.spotify.com/v1/audio-analysis/4AYh...
# danceability                                                  0.718
# duration_ms                                                  272147
# energy                                                        0.751
# id                                           4AYhsnQ43KBckV3RBagFPJ
# instrumentalness                                           1.78e-05
# key                                                               6
# liveness                                                      0.084
# loudness                                                     -5.965
# mode                                                              0
# speechiness                                                   0.033
# tempo                                                       101.971
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/4AYhsnQ43KBc...
# type                                                 audio_features
# uri                            spotify:track:4AYhsnQ43KBckV3RBagFPJ
# valence                                                       0.593
# Song Name                      Another Day in Paradise (with Ray J)
#
#                                                                1339  \
# acousticness                                                0.00136
# analysis_url      https://api.spotify.com/v1/audio-analysis/1StV...
# danceability                                                  0.677
# duration_ms                                                  337200
# energy                                                        0.678
# id                                           1StVq7G98jtRPttTbliku7
# instrumentalness                                            0.00478
# key                                                               7
# liveness                                                     0.0489
# loudness                                                     -6.983
# mode                                                              0
# speechiness                                                  0.0833
# tempo                                                       121.026
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/1StVq7G98jtR...
# type                                                 audio_features
# uri                            spotify:track:1StVq7G98jtRPttTbliku7
# valence                                                       0.404
# Song Name                              Love Injected - Karl G Remix
#
#                                                                1340  \
# acousticness                                                 0.0506
# analysis_url      https://api.spotify.com/v1/audio-analysis/6gQr...
# danceability                                                  0.691
# duration_ms                                                  223240
# energy                                                        0.927
# id                                           6gQrEwP4pFpszAnMfmASns
# instrumentalness                                           7.24e-06
# key                                                               4
# liveness                                                      0.132
# loudness                                                     -6.925
# mode                                                              1
# speechiness                                                  0.0297
# tempo                                                       127.997
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/6gQrEwP4pFps...
# type                                                 audio_features
# uri                            spotify:track:6gQrEwP4pFpszAnMfmASns
# valence                                                       0.926
# Song Name                                             King of Disco
#
#                                                                1341  \
# acousticness                                                  0.687
# analysis_url      https://api.spotify.com/v1/audio-analysis/1Yid...
# danceability                                                  0.707
# duration_ms                                                  194187
# energy                                                        0.656
# id                                           1Yid1jOsjDdITUUAL9I88s
# instrumentalness                                                  0
# key                                                               0
# liveness                                                      0.163
# loudness                                                     -5.588
# mode                                                              1
# speechiness                                                   0.104
# tempo                                                        90.182
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/1Yid1jOsjDdI...
# type                                                 audio_features
# uri                            spotify:track:1Yid1jOsjDdITUUAL9I88s
# valence                                                        0.77
# Song Name                        Unfoolish - Album Version (Edited)
#
#                                                                1342
# acousticness                                                 0.0337
# analysis_url      https://api.spotify.com/v1/audio-analysis/67NK...
# danceability                                                  0.685
# duration_ms                                                  259040
# energy                                                          0.6
# id                                           67NKaMOPOJKlWsYW6mVhSs
# instrumentalness                                           0.000365
# key                                                               9
# liveness                                                      0.156
# loudness                                                    -14.004
# mode                                                              0
# speechiness                                                  0.0517
# tempo                                                       103.015
# time_signature                                                    4
# track_href        https://api.spotify.com/v1/tracks/67NKaMOPOJKl...
# type                                                 audio_features
# uri                            spotify:track:67NKaMOPOJKlWsYW6mVhSs
# valence                                                       0.738
# Song Name                                     Take Him Back, Rachel
#
# [19 rows x 1349 columns]

# %% [markdown]
# ### cap_songs adjusts the case sensitive nature of the songs to match the songs on the join operation.

# %%
def cap_songs(song):
    parts = song.split('-')
    for i in range(len(parts)):
        parts[i] = parts[i].capitalize()
    return " ".join(parts)

# %%
dfCombined = dfCombined.set_index('Song Name')
dfCombined.head()
# Out:
#                         acousticness  \
# Song Name
# Pale Blue Face              0.000124
# Seperti Yang Kau Minta      0.287000
# Then Again                  0.586000
# Walk To The Bay             0.039800
# I Showed Her                0.674000
#
#                                                              analysis_url  \
# Song Name
# Pale Blue Face          https://api.spotify.com/v1/audio-analysis/0Ytl...
# Seperti Yang Kau Minta  https://api.spotify.com/v1/audio-analysis/2C0Y...
# Then Again              https://api.spotify.com/v1/audio-analysis/09at...
# Walk To The Bay         https://api.spotify.com/v1/audio-analysis/54k4...
# I Showed Her            https://api.spotify.com/v1/audio-analysis/3MPz...
#
#                         danceability  duration_ms  energy  \
# Song Name
# Pale Blue Face                 0.376       171293   0.948
# Seperti Yang Kau Minta         0.397       288813   0.446
# Then Again                     0.518       223840   0.203
# Walk To The Bay                0.570       182040   0.823
# I Showed Her                   0.640       265693   0.232
#
#                                             id  instrumentalness  key  \
# Song Name
# Pale Blue Face          0YtlU1KOPcxvNyiJTzqnCd          0.000104    9
# Seperti Yang Kau Minta  2C0YMWYyTjhRpEz1Xk42Hk          0.008660    4
# Then Again              09atT5JgSXIcq9v9H9qoQp          0.000002    9
# Walk To The Bay         54k4yt6SAkvlPcTMe4PKeC          0.000000    8
# I Showed Her            3MPzfijILwzlhhvBFKOTEB          0.000005    5
#
#                         liveness  loudness  mode  speechiness    tempo  \
# Song Name
# Pale Blue Face            0.1190    -4.683     1       0.1080   97.085
# Seperti Yang Kau Minta    0.1090    -7.411     1       0.0248  170.541
# Then Again                0.1470   -14.529     1       0.0275  103.305
# Walk To The Bay           0.0996    -4.761     1       0.0294  133.117
# I Showed Her              0.1040   -13.337     1       0.0270  147.676
#
#                         time_signature  \
# Song Name
# Pale Blue Face                       4
# Seperti Yang Kau Minta               4
# Then Again                           4
# Walk To The Bay                      4
# I Showed Her                         4
#
#                                                                track_href  \
# Song Name
# Pale Blue Face          https://api.spotify.com/v1/tracks/0YtlU1KOPcxv...
# Seperti Yang Kau Minta  https://api.spotify.com/v1/tracks/2C0YMWYyTjhR...
# Then Again              https://api.spotify.com/v1/tracks/09atT5JgSXIc...
# Walk To The Bay         https://api.spotify.com/v1/tracks/54k4yt6SAkvl...
# I Showed Her            https://api.spotify.com/v1/tracks/3MPzfijILwzl...
#
#                                   type                                   uri  \
# Song Name
# Pale Blue Face          audio_features  spotify:track:0YtlU1KOPcxvNyiJTzqnCd
# Seperti Yang Kau Minta  audio_features  spotify:track:2C0YMWYyTjhRpEz1Xk42Hk
# Then Again              audio_features  spotify:track:09atT5JgSXIcq9v9H9qoQp
# Walk To The Bay         audio_features  spotify:track:54k4yt6SAkvlPcTMe4PKeC
# I Showed Her            audio_features  spotify:track:3MPzfijILwzlhhvBFKOTEB
#
#                         valence
# Song Name
# Pale Blue Face            0.477
# Seperti Yang Kau Minta    0.199
# Then Again                0.144
# Walk To The Bay           0.930
# I Showed Her              0.263

# %%
songs['song'] = songs['song'].map(lambda x: cap_songs(x))
songs.head()
# Out:
#     index genre                                             lyrics  \
# 0  192053  Rock  It all started way back then A lifetime of rob...
# 1  231708  Rock  Amidst the burning rubble the spirit still liv...
# 2  350323  Rock  Is there anybody out there? Anyone that's love...
# 3   37853  Rock  Here is the room that we shared The room that ...
# 4  107765  Rock  I do it on a whim, its rhyme without reason wh...
#
#                          song         artist  \
# 0        Crime Of The Century   the-business
# 1               100 Years War        faction
# 2      How Do Ya Feel Tonight    bryan-adams
# 3  I Haven T Changed The Room  barry-manilow
# 4              Without Reason           fray
#
#                                 song_artist
# 0         crime-of-the-century:the-business
# 1                     100-years-war:faction
# 2        how-do-ya-feel-tonight:bryan-adams
# 3  i-haven-t-changed-the-room:barry-manilow
# 4                       without-reason:fray

# %%
songs = songs.set_index('song')
songs.head()
# Out:
#                              index genre  \
# song
# Crime Of The Century        192053  Rock
# 100 Years War               231708  Rock
# How Do Ya Feel Tonight      350323  Rock
# I Haven T Changed The Room   37853  Rock
# Without Reason              107765  Rock
#
#                                                                        lyrics  \
# song
# Crime Of The Century        It all started way back then A lifetime of rob...
# 100 Years War               Amidst the burning rubble the spirit still liv...
# How Do Ya Feel Tonight      Is there anybody out there? Anyone that's love...
# I Haven T Changed The Room  Here is the room that we shared The room that ...
# Without Reason              I do it on a whim, its rhyme without reason wh...
#
#                                    artist  \
# song
# Crime Of The Century         the-business
# 100 Years War                     faction
# How Do Ya Feel Tonight        bryan-adams
# I Haven T Changed The Room  barry-manilow
# Without Reason                       fray
#
#                                                          song_artist
# song
# Crime Of The Century               crime-of-the-century:the-business
# 100 Years War                                  100-years-war:faction
# How Do Ya Feel Tonight            how-do-ya-feel-tonight:bryan-adams
# I Haven T Changed The Room  i-haven-t-changed-the-room:barry-manilow
# Without Reason                                   without-reason:fray

# %%
songs.head()
# Out:
#                              index genre  \
# song
# Crime Of The Century        192053  Rock
# 100 Years War               231708  Rock
# How Do Ya Feel Tonight      350323  Rock
# I Haven T Changed The Room   37853  Rock
# Without Reason              107765  Rock
#
#                                                                        lyrics  \
# song
# Crime Of The Century        It all started way back then A lifetime of rob...
# 100 Years War               Amidst the burning rubble the spirit still liv...
# How Do Ya Feel Tonight      Is there anybody out there? Anyone that's love...
# I Haven T Changed The Room  Here is the room that we shared The room that ...
# Without Reason              I do it on a whim, its rhyme without reason wh...
#
#                                    artist  \
# song
# Crime Of The Century         the-business
# 100 Years War                     faction
# How Do Ya Feel Tonight        bryan-adams
# I Haven T Changed The Room  barry-manilow
# Without Reason                       fray
#
#                                                          song_artist
# song
# Crime Of The Century               crime-of-the-century:the-business
# 100 Years War                                  100-years-war:faction
# How Do Ya Feel Tonight            how-do-ya-feel-tonight:bryan-adams
# I Haven T Changed The Room  i-haven-t-changed-the-room:barry-manilow
# Without Reason                                   without-reason:fray

# %%
dfCombined.head()
# Out:
#                         acousticness  \
# Song Name
# Pale Blue Face              0.000124
# Seperti Yang Kau Minta      0.287000
# Then Again                  0.586000
# Walk To The Bay             0.039800
# I Showed Her                0.674000
#
#                                                              analysis_url  \
# Song Name
# Pale Blue Face          https://api.spotify.com/v1/audio-analysis/0Ytl...
# Seperti Yang Kau Minta  https://api.spotify.com/v1/audio-analysis/2C0Y...
# Then Again              https://api.spotify.com/v1/audio-analysis/09at...
# Walk To The Bay         https://api.spotify.com/v1/audio-analysis/54k4...
# I Showed Her            https://api.spotify.com/v1/audio-analysis/3MPz...
#
#                         danceability  duration_ms  energy  \
# Song Name
# Pale Blue Face                 0.376       171293   0.948
# Seperti Yang Kau Minta         0.397       288813   0.446
# Then Again                     0.518       223840   0.203
# Walk To The Bay                0.570       182040   0.823
# I Showed Her                   0.640       265693   0.232
#
#                                             id  instrumentalness  key  \
# Song Name
# Pale Blue Face          0YtlU1KOPcxvNyiJTzqnCd          0.000104    9
# Seperti Yang Kau Minta  2C0YMWYyTjhRpEz1Xk42Hk          0.008660    4
# Then Again              09atT5JgSXIcq9v9H9qoQp          0.000002    9
# Walk To The Bay         54k4yt6SAkvlPcTMe4PKeC          0.000000    8
# I Showed Her            3MPzfijILwzlhhvBFKOTEB          0.000005    5
#
#                         liveness  loudness  mode  speechiness    tempo  \
# Song Name
# Pale Blue Face            0.1190    -4.683     1       0.1080   97.085
# Seperti Yang Kau Minta    0.1090    -7.411     1       0.0248  170.541
# Then Again                0.1470   -14.529     1       0.0275  103.305
# Walk To The Bay           0.0996    -4.761     1       0.0294  133.117
# I Showed Her              0.1040   -13.337     1       0.0270  147.676
#
#                         time_signature  \
# Song Name
# Pale Blue Face                       4
# Seperti Yang Kau Minta               4
# Then Again                           4
# Walk To The Bay                      4
# I Showed Her                         4
#
#                                                                track_href  \
# Song Name
# Pale Blue Face          https://api.spotify.com/v1/tracks/0YtlU1KOPcxv...
# Seperti Yang Kau Minta  https://api.spotify.com/v1/tracks/2C0YMWYyTjhR...
# Then Again              https://api.spotify.com/v1/tracks/09atT5JgSXIc...
# Walk To The Bay         https://api.spotify.com/v1/tracks/54k4yt6SAkvl...
# I Showed Her            https://api.spotify.com/v1/tracks/3MPzfijILwzl...
#
#                                   type                                   uri  \
# Song Name
# Pale Blue Face          audio_features  spotify:track:0YtlU1KOPcxvNyiJTzqnCd
# Seperti Yang Kau Minta  audio_features  spotify:track:2C0YMWYyTjhRpEz1Xk42Hk
# Then Again              audio_features  spotify:track:09atT5JgSXIcq9v9H9qoQp
# Walk To The Bay         audio_features  spotify:track:54k4yt6SAkvlPcTMe4PKeC
# I Showed Her            audio_features  spotify:track:3MPzfijILwzlhhvBFKOTEB
#
#                         valence
# Song Name
# Pale Blue Face            0.477
# Seperti Yang Kau Minta    0.199
# Then Again                0.144
# Walk To The Bay           0.930
# I Showed Her              0.263

# %% [markdown]
# ### Inner join the songs on the ID

# %%
dfFinal = dfCombined.join(songs, how='inner')
dfFinal['genre'].value_counts()
# Out:
# Rock    460
# Pop     325
# Name: genre, dtype: int64

# %%
dfFinal.to_csv("additional_features_pop_rock_miheer.csv")
